# %% [markdown]
# Initial Data Cleaning of Zillow Data.

# %%
import os
import pandas as pd

# %%
path1 = os.getcwd()
path2 = path[:-9] + '\\data\\raw'
os.chdir(path2)
os.listdir()
# Out:
# ['.gitkeep',
#  'all_available_metrics.json',
#  'archive.zip',
#  'cities_crosswalk.csv',
#  'City_time_series.csv',
#  'CountyCrossWalk_Zillow.csv',
#  'County_time_series.csv',
#  'DataDictionary.csv',
#  'fields_per_level.json',
#  'Metro_time_series.csv',
#  'Neighborhood_time_series.csv',
#  'State_time_series.csv',
#  'Zip_time_series.csv']

# %%
os.chdir(path1)

# %%
df = pd.read_csv(path2+'\\Zip_time_series.csv')

# %%
df.describe()
# Out:
#          RegionName  InventorySeasonallyAdjusted_AllHomes  \
# count  4.383885e+06                          1.051104e+06
# mean   4.683726e+04                          1.230490e+02
# std    2.883334e+04                          1.172875e+02
# min    7.450000e+02                          3.000000e+00
# 25%    2.183000e+04                          4.600000e+01
# 50%    4.466900e+04                          8.800000e+01
# 75%    7.271800e+04                          1.600000e+02
# max    9.990100e+04                          2.560000e+03
#
#        InventoryRaw_AllHomes  MedianListingPricePerSqft_1Bedroom  \
# count           1.051104e+06                         8194.000000
# mean            1.230721e+02                          322.914946
# std             1.180173e+02                          301.027216
# min             2.000000e+00                           24.793388
# 25%             4.600000e+01                          155.056896
# ...

# %%
df.head()
# Out:
#          Date  RegionName  InventorySeasonallyAdjusted_AllHomes  \
# 0  1996-04-30        1001                                   NaN
# 1  1996-04-30        1002                                   NaN
# 2  1996-04-30        1005                                   NaN
# 3  1996-04-30        1007                                   NaN
# 4  1996-04-30        1008                                   NaN
#
#    InventoryRaw_AllHomes  MedianListingPricePerSqft_1Bedroom  \
# 0                    NaN                                 NaN
# 1                    NaN                                 NaN
# 2                    NaN                                 NaN
# 3                    NaN                                 NaN
# 4                    NaN                                 NaN
#
#    MedianListingPricePerSqft_2Bedroom  MedianListingPricePerSqft_3Bedroom  \
# 0                                 NaN                                 NaN
# ...

# %%
columns = df.columns

# %%
columns
# Out:
# Index(['Date', 'RegionName', 'InventorySeasonallyAdjusted_AllHomes',
#        'InventoryRaw_AllHomes', 'MedianListingPricePerSqft_1Bedroom',
#        'MedianListingPricePerSqft_2Bedroom',
#        'MedianListingPricePerSqft_3Bedroom',
#        'MedianListingPricePerSqft_4Bedroom',
#        'MedianListingPricePerSqft_5BedroomOrMore',
#        'MedianListingPricePerSqft_AllHomes',
#        'MedianListingPricePerSqft_CondoCoop',
#        'MedianListingPricePerSqft_DuplexTriplex',
#        'MedianListingPricePerSqft_SingleFamilyResidence',
#        'MedianListingPrice_1Bedroom', 'MedianListingPrice_2Bedroom',
#        'MedianListingPrice_3Bedroom', 'MedianListingPrice_4Bedroom',
#        'MedianListingPrice_5BedroomOrMore', 'MedianListingPrice_AllHomes',
#        'MedianListingPrice_CondoCoop', 'MedianListingPrice_DuplexTriplex',
#        'MedianListingPrice_SingleFamilyResidence',
#        'MedianPctOfPriceReduction_AllHomes',
#        'MedianPctOfPriceReduction_CondoCoop',
# ...

# %%
df['RegionName'].unique()
# Out:
# array([ 1001,  1002,  1005, ..., 73102, 78215, 78235], dtype=int64)

# %%
df.loc[df['RegionName'] == '78728']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-f907ff966e9b> in <module>()
# ----> 1 df.loc[df['RegionName'] == '78728']
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     244             warnings.simplefilter("ignore", DeprecationWarning)
# ...

# %%
type(df['RegionName'][0])
# Out:
# numpy.int64

# %%
df.loc[df['RegionName'] == 78728]
# Out:
#                Date  RegionName  InventorySeasonallyAdjusted_AllHomes  \
# 150008   1997-02-28       78728                                   NaN
# 164746   1997-03-31       78728                                   NaN
# 179495   1997-04-30       78728                                   NaN
# 194244   1997-05-31       78728                                   NaN
# 208990   1997-06-30       78728                                   NaN
# ...             ...         ...                                   ...
# 4304424  2017-08-31       78728                                   NaN
# 4323471  2017-09-30       78728                                   NaN
# 4342518  2017-10-31       78728                                   NaN
# 4361565  2017-11-30       78728                                   NaN
# 4380612  2017-12-31       78728                                   NaN
#
#          InventoryRaw_AllHomes  MedianListingPricePerSqft_1Bedroom  \
# ...

# %%
san_antonio_zipcodes = [78201, 78202, 78203, 78204, 78205, 78206, 78207, 78208, 78209, 78210, 78211, 78212, 78213, 78214, 78215, 78216, 78217, 78218, 78219, 78220, 78221, 78222, 78223, 78224, 78225, 78226, 78227, 78228, 78229, 78230, 78231, 78232, 78233, 78234, 78235, 78236, 78237, 78238, 78239, 78240, 78241, 78242, 78243, 78244, 78245, 78246, 78247, 78248, 78249, 78250, 78251, 78252, 78253, 78254, 78255, 78256, 78257, 78258, 78259, 78260, 78261, 78262, 78263, 78264, 78265, 78266, 78268, 78269, 78270, 78275, 78278, 78279, 78280, 78283, 78284, 78285, 78286, 78287, 78288, 78289, 78291, 78292, 78293, 78294, 78295, 78296, 78297, 78298, 78299]

# %%
df['RegionName'].isin(san_antonio_zipcodes)
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 4383880    False
# 4383881    False
# 4383882    False
# 4383883    False
# 4383884    False
# Name: RegionName, Length: 4383885, dtype: bool

# %%
sat_subset_index = df['RegionName'].isin(san_antonio_zipcodes)

# %%
sat_subset = df[sat_subset_index]

# %%
sat_subset.head()
# Out:
#              Date  RegionName  InventorySeasonallyAdjusted_AllHomes  \
# 10799  1996-04-30       78253                                   NaN
# 10800  1996-04-30       78266                                   NaN
# 24563  1996-05-31       78253                                   NaN
# 24564  1996-05-31       78266                                   NaN
# 38363  1996-06-30       78253                                   NaN
#
#        InventoryRaw_AllHomes  MedianListingPricePerSqft_1Bedroom  \
# 10799                    NaN                                 NaN
# 10800                    NaN                                 NaN
# 24563                    NaN                                 NaN
# 24564                    NaN                                 NaN
# 38363                    NaN                                 NaN
#
#        MedianListingPricePerSqft_2Bedroom  MedianListingPricePerSqft_3Bedroom  \
# 10799                                 NaN                                 NaN
# ...

# %%
sat_subset.describe()
# Out:
#          RegionName  InventorySeasonallyAdjusted_AllHomes  \
# count  12714.000000                           3552.000000
# mean   78233.708353                            151.592342
# std       18.897203                            132.107118
# min    78201.000000                             11.000000
# 25%    78218.000000                             60.000000
# 50%    78232.000000                            102.000000
# 75%    78251.000000                            206.250000
# max    78266.000000                            889.000000
#
#        InventoryRaw_AllHomes  MedianListingPricePerSqft_1Bedroom  \
# count            3552.000000                                 0.0
# mean              151.663570                                 NaN
# std               132.924431                                 NaN
# min                10.000000                                 NaN
# 25%                60.000000                                 NaN
# ...

# %%
len(columns)
# Out:
# 76

# %%
sat_subset['ZHVI_1bedroom'].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: ZHVI_1bedroom, dtype: float64

# %%
sat_subset['MedianListingPricePerSqft_1Bedroom'].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: MedianListingPricePerSqft_1Bedroom, dtype: float64

# %%
sat_family_homes = sat_subset[['Date', 'RegionName', 'InventorySeasonallyAdjusted_AllHomes',
       'InventoryRaw_AllHomes','MedianListingPricePerSqft_2Bedroom',
       'MedianListingPricePerSqft_3Bedroom',
       'MedianListingPricePerSqft_4Bedroom',
       'MedianListingPricePerSqft_5BedroomOrMore',
       'MedianListingPricePerSqft_AllHomes',
       'MedianListingPricePerSqft_CondoCoop',
       'MedianListingPricePerSqft_DuplexTriplex',
       'MedianListingPricePerSqft_SingleFamilyResidence',
       'MedianListingPrice_1Bedroom', 'MedianListingPrice_2Bedroom',
       'MedianListingPrice_3Bedroom', 'MedianListingPrice_4Bedroom',
       'MedianListingPrice_5BedroomOrMore', 'MedianListingPrice_AllHomes',
       'MedianListingPrice_CondoCoop', 'MedianListingPrice_DuplexTriplex']]

# %%
sat_family_homes.describe()
# Out:
#          RegionName  InventorySeasonallyAdjusted_AllHomes  \
# count  12714.000000                           3552.000000
# mean   78233.708353                            151.592342
# std       18.897203                            132.107118
# min    78201.000000                             11.000000
# 25%    78218.000000                             60.000000
# 50%    78232.000000                            102.000000
# 75%    78251.000000                            206.250000
# max    78266.000000                            889.000000
#
#        InventoryRaw_AllHomes  MedianListingPricePerSqft_2Bedroom  \
# count            3552.000000                           28.000000
# mean              151.663570                          148.072755
# std               132.924431                            3.985732
# min                10.000000                          137.832714
# 25%                60.000000                          145.669317
# ...

# %%
sat_family_homes[['Date', 'MedianListingPricePerSqft_2Bedroom']]
# Out:
#                Date  MedianListingPricePerSqft_2Bedroom
# 10799    1996-04-30                                 NaN
# 10800    1996-04-30                                 NaN
# 24563    1996-05-31                                 NaN
# 24564    1996-05-31                                 NaN
# 38363    1996-06-30                                 NaN
# ...             ...                                 ...
# 4380475  2017-12-31                                 NaN
# 4380476  2017-12-31                                 NaN
# 4380477  2017-12-31                                 NaN
# 4380478  2017-12-31                                 NaN
# 4380479  2017-12-31                                 NaN
#
# [12714 rows x 2 columns]

# %% [markdown]
# There are only 28 data points for 2 bedroom houses in San Antonio for the Median Listing Price per SQFT

# %%
len(sat_subset['RegionName'].unique())
# Out:
# 57

# %%
columns
# Out:
# Index(['Date', 'RegionName', 'InventorySeasonallyAdjusted_AllHomes',
#        'InventoryRaw_AllHomes', 'MedianListingPricePerSqft_1Bedroom',
#        'MedianListingPricePerSqft_2Bedroom',
#        'MedianListingPricePerSqft_3Bedroom',
#        'MedianListingPricePerSqft_4Bedroom',
#        'MedianListingPricePerSqft_5BedroomOrMore',
#        'MedianListingPricePerSqft_AllHomes',
#        'MedianListingPricePerSqft_CondoCoop',
#        'MedianListingPricePerSqft_DuplexTriplex',
#        'MedianListingPricePerSqft_SingleFamilyResidence',
#        'MedianListingPrice_1Bedroom', 'MedianListingPrice_2Bedroom',
#        'MedianListingPrice_3Bedroom', 'MedianListingPrice_4Bedroom',
#        'MedianListingPrice_5BedroomOrMore', 'MedianListingPrice_AllHomes',
#        'MedianListingPrice_CondoCoop', 'MedianListingPrice_DuplexTriplex',
#        'MedianListingPrice_SingleFamilyResidence',
#        'MedianPctOfPriceReduction_AllHomes',
#        'MedianPctOfPriceReduction_CondoCoop',
# ...

# %%
TwoBedroom_drop = [s for s in columns if "2Bed" in s]
#Create a list to drop the 2bedroom houses from the list since we only have 28 datapoints.

# %%
TwoBedroom_drop
# Out:
# ['MedianListingPricePerSqft_2Bedroom',
#  'MedianListingPrice_2Bedroom',
#  'MedianRentalPricePerSqft_2Bedroom',
#  'MedianRentalPrice_2Bedroom']
